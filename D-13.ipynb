# %% [markdown]
# ## MACHINE LEARNING MODEL FOR FOOD ADULTERATION ANALYSIS

# %%
import warnings
warnings.filterwarnings('ignore')
import joblib
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score

# %%
df=pd.read_csv('food_adulteration.csv')

# %%
df.head()
# Out:
#    adulteration_id product_name   brand   category             adulterant  \
# 0                1       Butter  BrandB       Meat  Artificial sweeteners
# 1                2      Chicken  BrandC      Dairy        Coloring agents
# 2                3       Yogurt  BrandC       Meat  Artificial sweeteners
# 3                4         Wine  BrandB  Beverages        Coloring agents
# 4                5        Bread  BrandD      Dairy                  Water
#
#   detection_date          detection_method  severity health_risk  \
# 0      5/11/2024  Microbiological Analysis  Moderate         Low
# 1      5/23/2024        Sensory Evaluation    Severe      Medium
# 2      2/17/2024        Sensory Evaluation    Severe        High
# 3      5/16/2024              Spectroscopy     Minor      Medium
# 4       6/6/2024         Chemical Analysis    Severe      Medium
#
#              action_taken
# 0          Product Recall
# 1          Warning Issued
# 2  Investigation Launched
# 3          Product Recall
# 4          Warning Issued

# %% [markdown]
# ## Data preprocessing:

# %%
df.shape
# Out:
# (900, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   adulteration_id   900 non-null    int64
#  1   product_name      900 non-null    object
#  2   brand             900 non-null    object
#  3   category          900 non-null    object
#  4   adulterant        900 non-null    object
#  5   detection_date    900 non-null    object
#  6   detection_method  900 non-null    object
#  7   severity          900 non-null    object
#  8   health_risk       900 non-null    object
#  9   action_taken      900 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        adulteration_id
# count       900.000000
# mean        500.355556
# std         289.967319
# min           1.000000
# 25%         248.750000
# 50%         499.500000
# 75%         755.250000
# max        1000.000000

# %%
df.nunique()
# Out:
# adulteration_id     900
# product_name         10
# brand                 5
# category              5
# adulterant            5
# detection_date      181
# detection_method      4
# severity              3
# health_risk           3
# action_taken          4
# dtype: int64

# %% [markdown]
# ## Data cleaning:

# %%
# to check the null values:
df.isnull().sum()
# Out:
# adulteration_id     0
# product_name        0
# brand               0
# category            0
# adulterant          0
# detection_date      0
# detection_method    0
# severity            0
# health_risk         0
# action_taken        0
# dtype: int64

# %%
# to check the duplicate values:
df.duplicated().sum()
# Out:
# 0

# %%
df = resample(df, replace=True, n_samples=16500, random_state=42)

# %% [markdown]
# ## Exploratory data anlaysis:

# %%
# count plot for adulterant column:
sns.set(style="darkgrid")
plt.figure(figsize=(8,6))
ax=sns.countplot(x='action_taken',data=df)
plt.title('count plot')
plt.xlabel('adulterant')
plt.ylabel('count')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()

# %%
df['action_taken'].unique()
# Out:
# array(['Fine Imposed', 'Warning Issued', 'Product Recall',
#        'Investigation Launched'], dtype=object)

# %%
labels=['Fine Imposed', 'Warning Issued', 'Product Recall',
       'Investigation Launched']

# %% [markdown]
# ## Label encoding:

# %%
df.head()
# Out:
#      adulteration_id product_name   brand   category       adulterant  \
# 102              116       Cheese  BrandC      Dairy  Coloring agents
# 435              482       Cheese  BrandC  Beverages  Coloring agents
# 860              955       Cheese  BrandA       Meat            Chalk
# 270              298         Beef  BrandE     Bakery         Melamine
# 106              121      Chicken  BrandB     Bakery         Melamine
#
#     detection_date          detection_method  severity health_risk  \
# 102      1/15/2024  Microbiological Analysis    Severe         Low
# 435      4/11/2024         Chemical Analysis     Minor         Low
# 860      5/18/2024              Spectroscopy  Moderate      Medium
# 270      2/17/2024         Chemical Analysis    Severe        High
# 106       3/5/2024         Chemical Analysis  Moderate      Medium
#
#                action_taken
# 102            Fine Imposed
# 435          Warning Issued
# 860          Product Recall
# 270  Investigation Launched
# 106          Product Recall

# %%
# to convert the object type columns to numerical columns:
le=LabelEncoder()

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])

# %%
df.head()
# Out:
#      adulteration_id  product_name  brand  category  adulterant  \
# 102              116             3      2         3           2
# 435              482             3      2         1           2
# 860              955             3      0         4           1
# 270              298             0      4         0           3
# 106              121             4      1         0           3
#
#      detection_date  detection_method  severity  health_risk  action_taken
# 102               6                 1         2            1             0
# 435              93                 0         0            1             3
# 860             129                 3         1            2             2
# 270              39                 0         2            0             1
# 106              86                 0         1            2             2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16500 entries, 102 to 832
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   adulteration_id   16500 non-null  int64
#  1   product_name      16500 non-null  int32
#  2   brand             16500 non-null  int32
#  3   category          16500 non-null  int32
#  4   adulterant        16500 non-null  int32
#  5   detection_date    16500 non-null  int32
#  6   detection_method  16500 non-null  int32
#  7   severity          16500 non-null  int32
#  8   health_risk       16500 non-null  int32
#  9   action_taken      16500 non-null  int32
# dtypes: int32(9), int64(1)
# memory usage: 1.3 MB

# %%
# x and y variable separation:
x = df.drop(columns=['action_taken'])

# %%
x
# Out:
#      adulteration_id  product_name  brand  category  adulterant  \
# 102              116             3      2         3           2
# 435              482             3      2         1           2
# 860              955             3      0         4           1
# 270              298             0      4         0           3
# 106              121             4      1         0           3
# ..               ...           ...    ...       ...         ...
# 154              173             1      3         0           4
# 648              726             4      2         2           2
# 502              558             1      2         2           4
# 678              761             2      2         2           4
# 832              925             4      3         4           4
#
#      detection_date  detection_method  severity  health_risk
# 102               6                 1         2            1
# 435              93                 0         0            1
# 860             129                 3         1            2
# 270              39                 0         2            0
# 106              86                 0         1            2
# ..              ...               ...       ...          ...
# 154              31                 3         2            1
# 648             117                 3         1            1
# 502             161                 2         0            2
# 678              70                 3         2            2
# 832              60                 0         0            1
#
# [16500 rows x 9 columns]

# %%
y = df.loc[:,'action_taken']

# %%
y
# Out:
# 102    0
# 435    3
# 860    2
# 270    1
# 106    2
#       ..
# 154    3
# 648    1
# 502    2
# 678    1
# 832    3
# Name: action_taken, Length: 16500, dtype: int32

# %%
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %%
# train, test and splitting of data:

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (13200, 9)

# %%
y_train.shape
# Out:
# (13200,)

# %%
x_test.shape
# Out:
# (3300, 9)

# %%
y_test.shape
# Out:
# (3300,)

# %% [markdown]
# ## Applying SMOTE:

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42)

# %%
x_resampled, y_resampled = smote.fit_resample(x_train, y_train)

# %%
print("Original training set shape:", x_train.shape, y_train.shape)
print("Resampled training set shape:", x_resampled.shape, y_resampled.shape)
# Out:
# Original training set shape: (13200, 9) (13200,)
# Resampled training set shape: (13736, 9) (13736,)

# %%
df_resampled = pd.DataFrame(x_resampled, columns=df.columns[:-1])
df_resampled['target'] = y_resampled

# Count the occurrences of each class
class_counts = df_resampled['target'].value_counts()
print("Class distribution after applying SMOTE:\n", class_counts)
# Out:
# Class distribution after applying SMOTE:
#  2    3434
# 3    3434
# 1    3434
# 0    3434
# Name: target, dtype: int64

# %%
# Visualize the class distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title('Class Distribution After Applying SMOTE')
plt.show()

# %% [markdown]
# ## Performance Metrics Evaluation:

# %%
#defining global variables to store accuracy and other metrics
precision = []
recall = []
fscore = []
accuracy = []

# %%
#function to calculate various metrics such as accuracy, precision etc
def calculateMetrics(algorithm, testY,predict):
    testY = testY.astype('int')
    predict = predict.astype('int')
    p = precision_score(testY, predict,average='macro') * 100
    r = recall_score(testY, predict,average='macro') * 100
    f = f1_score(testY, predict,average='macro') * 100
    a = accuracy_score(testY,predict)*100 
    accuracy.append(a)
    precision.append(p)
    recall.append(r)
    fscore.append(f)
    print(algorithm+' Accuracy    : '+str(a))
    print(algorithm+' Precision   : '+str(p))
    print(algorithm+' Recall      : '+str(r))
    print(algorithm+' FSCORE      : '+str(f))
    report=classification_report(predict, testY,target_names=labels)
    print('\n',algorithm+" classification report\n",report)
    conf_matrix = confusion_matrix(testY, predict) 
    plt.figure(figsize =(5, 5)) 
    ax = sns.heatmap(conf_matrix, xticklabels = labels, yticklabels = labels, annot = True, cmap="Blues" ,fmt ="g");
    ax.set_ylim([0,len(labels)])
    plt.title(algorithm+" Confusion matrix") 
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %% [markdown]
# ## Gradient Boost Classifier:

# %%
#gbc model:
if os.path.exists('GradientBoostClassifier.pkl'):
    #load the model:
    gbc=joblib.load('GradientBoostClassifier.pkl')
    print('model loaded successfully')
    predict=gbc.predict(x_test)
    calculateMetrics("KNeighborsClassifier",predict,y_test)
else:
    #train the model:
    gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.7, max_depth=3, random_state=42,)
    gbc.fit(x_resampled,y_resampled)
    #saving model:
    joblib.dump(gbc,'GradientBoostClassifier.pkl')
    print('model saved successfully')
    predict=gbc.predict(x_test)
    calculateMetrics("GradientBoostClassifier",predict,y_test)
# Out:
# model loaded successfully
# KNeighborsClassifier Accuracy    : 77.6969696969697
# KNeighborsClassifier Precision   : 77.74917243007128
# KNeighborsClassifier Recall      : 78.3456876406422
# KNeighborsClassifier FSCORE      : 77.8447322258609
#
#  KNeighborsClassifier classification report
#                          precision    recall  f1-score   support
#
#           Fine Imposed       0.72      0.77      0.74       803
#         Warning Issued       0.73      0.82      0.77       877
#         Product Recall       0.85      0.73      0.78       874
# Investigation Launched       0.84      0.80      0.82       746
#
#               accuracy                           0.78      3300
#              macro avg       0.78      0.78      0.78      3300
#           weighted avg       0.78      0.78      0.78      3300

# %% [markdown]
# ## Knn classifier:

# %%
#knn model:
if os.path.exists('KNeighborsClassifier.pkl'):
    #load the model:
    knn=joblib.load('KNeighborsClassifier.pkl')
    print('model loaded successfully')
    predict=knn.predict(x_test)
    calculateMetrics("KNeighborsClassifier",predict,y_test)
else:
    #train the model:
    knn=KNeighborsClassifier()
    knn.fit(x_resampled,y_resampled)
    #saving model:
    joblib.dump(knn,'KNeighborsClassifier.pkl')
    print('model saved successfully')
    predict=knn.predict(x_test)
    calculateMetrics("KNeighborsClassifier",predict,y_test)
# Out:
# model loaded successfully
# KNeighborsClassifier Accuracy    : 100.0
# KNeighborsClassifier Precision   : 100.0
# KNeighborsClassifier Recall      : 100.0
# KNeighborsClassifier FSCORE      : 100.0
#
#  KNeighborsClassifier classification report
#                          precision    recall  f1-score   support
#
#           Fine Imposed       1.00      1.00      1.00       803
#         Warning Issued       1.00      1.00      1.00       877
#         Product Recall       1.00      1.00      1.00       874
# Investigation Launched       1.00      1.00      1.00       746
#
#               accuracy                           1.00      3300
#              macro avg       1.00      1.00      1.00      3300
#           weighted avg       1.00      1.00      1.00      3300

# %%
#showing all algorithms performance values
columns = ["Algorithm Name","Precison","Recall","FScore","Accuracy"]
values = []
algorithm_names = ["Gradient Boost Classifier",'KNeighbor Classifier']
for i in range(len(algorithm_names)):
    values.append([algorithm_names[i],precision[i],recall[i],fscore[i],accuracy[i]])
    
temp = pd.DataFrame(values,columns=columns)
temp
# Out:
#               Algorithm Name    Precison      Recall      FScore   Accuracy
# 0  Gradient Boost Classifier   77.749172   78.345688   77.844732   77.69697
# 1       KNeighbor Classifier  100.000000  100.000000  100.000000  100.00000

# %%
# importing test dataset:
test=pd.read_csv("test.csv")

# %%
test = test.drop('action_taken',axis=1)

# %%
test.head()
# Out:
#    adulteration_id product_name   brand    category       adulterant  \
# 0              508         Wine  BrandD   Beverages  Coloring agents
# 1              819      Chicken  BrandD   Beverages            Water
# 2              453         Wine  BrandE      Bakery            Chalk
# 3              369         Milk  BrandC  Condiments         Melamine
# 4              243      Chicken  BrandD        Meat  Coloring agents
#
#   detection_date          detection_method  severity health_risk
# 0      5/10/2024              Spectroscopy  Moderate         Low
# 1      5/10/2024  Microbiological Analysis  Moderate      Medium
# 2      1/20/2024         Chemical Analysis     Minor         Low
# 3      2/25/2024              Spectroscopy    Severe        High
# 4      6/15/2024  Microbiological Analysis    Severe        High

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   adulteration_id   100 non-null    int64
#  1   product_name      100 non-null    object
#  2   brand             100 non-null    object
#  3   category          100 non-null    object
#  4   adulterant        100 non-null    object
#  5   detection_date    100 non-null    object
#  6   detection_method  100 non-null    object
#  7   severity          100 non-null    object
#  8   health_risk       100 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 7.2+ KB

# %%
labels
# Out:
# ['Fine Imposed', 'Warning Issued', 'Product Recall', 'Investigation Launched']

# %% [markdown]
# ## Label encoding

# %%
for column in test.columns:
    if test[column].dtype == 'object':
        test[column] = le.fit_transform(test[column])

# %%
# Make predictions on the selected test data
predict = knn.predict(test)
# Loop through each prediction and print the corresponding row
for i, p in enumerate(predict):
    if p == 0:
        print(test.iloc[i])
        print("Row {}:************************************************** Fine Imposed ".format(i))
    elif p==1:
        print(test.iloc[i])
        print("Row {}:************************************************** Warning Issued".format(i))
    elif p==2:
        print(test.iloc[i])
        print("Row {}:************************************************** Product Recall".format(i))
    elif p==3:
        print(test.iloc[i])
        print("Row {}:************************************************** Investigation Launched".format(i))
# Out:
# adulteration_id     508
# product_name          8
# brand                 3
# category              1
# adulterant            2
# detection_date       49
# detection_method      3
# severity              1
# health_risk           1
# Name: 0, dtype: int64
# Row 0:************************************************** Investigation Launched
# adulteration_id     819
# product_name          4
# brand                 3
# category              1
# adulterant            4
# detection_date       49
# detection_method      1
# severity              1
# health_risk           2
# Name: 1, dtype: int64
# Row 1:************************************************** Investigation Launched
# adulteration_id     453
# product_name          8
# brand                 4
# category              0
# adulterant            1
# detection_date        5
# detection_method      0
# severity              0
# health_risk           1
# Name: 2, dtype: int64
# Row 2:************************************************** Product Recall
# adulteration_id     369
# product_name          7
# brand                 2
# category              2
# adulterant            3
# detection_date       21
# detection_method      3
# severity              2
# health_risk           0
# Name: 3, dtype: int64
# Row 3:************************************************** Investigation Launched
# adulteration_id     243
# product_name          4
# brand                 3
# category              4
# adulterant            2
# detection_date       61
# detection_method      1
# severity              2
# health_risk           0
# Name: 4, dtype: int64
# Row 4:************************************************** Product Recall
# adulteration_id     930
# product_name          9
# brand                 2
# category              3
# adulterant            4
# detection_date       33
# detection_method      1
# severity              1
# health_risk           1
# Name: 5, dtype: int64
# Row 5:************************************************** Investigation Launched
# adulteration_id     263
# product_name          1
# brand                 1
# category              2
# adulterant            2
# detection_date       45
# detection_method      2
# severity              1
# health_risk           1
# Name: 6, dtype: int64
# Row 6:************************************************** Product Recall
# adulteration_id     811
# product_name          5
# brand                 4
# category              0
# adulterant            3
# detection_date       52
# detection_method      3
# severity              2
# health_risk           0
# Name: 7, dtype: int64
# Row 7:************************************************** Investigation Launched
# adulteration_id     319
# product_name          5
# brand                 0
# category              3
# adulterant            4
# detection_date       35
# detection_method      1
# severity              1
# health_risk           1
# Name: 8, dtype: int64
# Row 8:************************************************** Investigation Launched
# adulteration_id     50
# product_name         2
# brand                4
# category             1
# adulterant           1
# detection_date      64
# detection_method     0
# severity             0
# health_risk          1
# Name: 9, dtype: int64
# Row 9:************************************************** Product Recall
# adulteration_id     447
# product_name          9
# brand                 0
# category              1
# adulterant            0
# detection_date       55
# detection_method      0
# severity              0
# health_risk           0
# Name: 10, dtype: int64
# Row 10:************************************************** Investigation Launched
# adulteration_id     143
# product_name          2
# brand                 0
# category              3
# adulterant            2
# detection_date       70
# detection_method      2
# severity              0
# health_risk           0
# Name: 11, dtype: int64
# Row 11:************************************************** Product Recall
# adulteration_id     969
# product_name          1
# brand                 3
# category              3
# adulterant            2
# detection_date       14
# detection_method      1
# severity              2
# health_risk           0
# Name: 12, dtype: int64
# Row 12:************************************************** Investigation Launched
# adulteration_id     346
# product_name          6
# brand                 4
# category              4
# adulterant            0
# detection_date       22
# detection_method      1
# severity              0
# health_risk           2
# Name: 13, dtype: int64
# Row 13:************************************************** Investigation Launched
# adulteration_id     972
# product_name          8
# brand                 2
# category              3
# adulterant            0
# detection_date       45
# detection_method      0
# severity              1
# health_risk           2
# Name: 14, dtype: int64
# Row 14:************************************************** Investigation Launched
# adulteration_id     134
# product_name          1
# brand                 4
# category              4
# adulterant            3
# detection_date        7
# detection_method      0
# severity              1
# health_risk           1
# Name: 15, dtype: int64
# Row 15:************************************************** Product Recall
# adulteration_id     105
# product_name          7
# brand                 0
# category              3
# adulterant            4
# detection_date       51
# detection_method      2
# severity              2
# health_risk           2
# Name: 16, dtype: int64
# Row 16:************************************************** Product Recall
# adulteration_id      7
# product_name         0
# brand                2
# category             4
# adulterant           3
# detection_date      38
# detection_method     0
# severity             0
# health_risk          2
# Name: 17, dtype: int64
# Row 17:************************************************** Product Recall
# adulteration_id     601
# product_name          9
# brand                 3
# category              1
# adulterant            0
# detection_date       46
# detection_method      1
# severity              1
# health_risk           2
# Name: 18, dtype: int64
# Row 18:************************************************** Investigation Launched
# adulteration_id     497
# product_name          0
# brand                 2
# category              0
# adulterant            0
# detection_date        0
# detection_method      1
# severity              2
# health_risk           0
# Name: 19, dtype: int64
# Row 19:************************************************** Product Recall
# adulteration_id     703
# product_name          5
# brand                 0
# category              2
# adulterant            0
# detection_date       11
# detection_method      2
# severity              1
# health_risk           1
# Name: 20, dtype: int64
# Row 20:************************************************** Investigation Launched
# adulteration_id     473
# product_name          7
# brand                 4
# category              2
# adulterant            3
# detection_date       16
# detection_method      2
# severity              2
# health_risk           1
# Name: 21, dtype: int64
# Row 21:************************************************** Investigation Launched
# adulteration_id     599
# product_name          8
# brand                 0
# category              0
# adulterant            3
# detection_date       28
# detection_method      3
# severity              0
# health_risk           0
# Name: 22, dtype: int64
# Row 22:************************************************** Investigation Launched
# adulteration_id     503
# product_name          6
# brand                 1
# category              3
# adulterant            2
# detection_date       54
# detection_method      2
# severity              2
# health_risk           0
# Name: 23, dtype: int64
# Row 23:************************************************** Investigation Launched
# adulteration_id     434
# product_name          3
# brand                 3
# category              1
# adulterant            0
# detection_date       25
# detection_method      2
# severity              1
# health_risk           0
# Name: 24, dtype: int64
# Row 24:************************************************** Investigation Launched
# adulteration_id     120
# product_name          6
# brand                 2
# category              3
# adulterant            4
# detection_date       57
# detection_method      3
# severity              0
# health_risk           1
# Name: 25, dtype: int64
# Row 25:************************************************** Product Recall
# adulteration_id     109
# product_name          8
# brand                 2
# category              1
# adulterant            0
# detection_date       71
# detection_method      3
# severity              0
# health_risk           2
# Name: 26, dtype: int64
# Row 26:************************************************** Product Recall
# adulteration_id     648
# product_name          3
# brand                 2
# category              1
# adulterant            3
# detection_date       22
# detection_method      1
# severity              0
# health_risk           1
# Name: 27, dtype: int64
# Row 27:************************************************** Investigation Launched
# adulteration_id     590
# product_name          2
# brand                 2
# category              2
# adulterant            3
# detection_date       29
# detection_method      2
# severity              2
# health_risk           2
# Name: 28, dtype: int64
# Row 28:************************************************** Investigation Launched
# adulteration_id     375
# product_name          7
# brand                 3
# category              3
# adulterant            4
# detection_date       16
# detection_method      0
# severity              2
# health_risk           1
# Name: 29, dtype: int64
# Row 29:************************************************** Investigation Launched
# adulteration_id     911
# product_name          1
# brand                 4
# category              2
# adulterant            2
# detection_date       33
# detection_method      3
# severity              1
# health_risk           1
# Name: 30, dtype: int64
# Row 30:************************************************** Investigation Launched
# adulteration_id     719
# product_name          1
# brand                 0
# category              1
# adulterant            3
# detection_date       44
# detection_method      2
# severity              0
# health_risk           1
# Name: 31, dtype: int64
# Row 31:************************************************** Investigation Launched
# adulteration_id     745
# product_name          6
# brand                 3
# category              4
# adulterant            0
# detection_date       11
# detection_method      1
# severity              0
# health_risk           1
# Name: 32, dtype: int64
# Row 32:************************************************** Investigation Launched
# adulteration_id     495
# product_name          6
# brand                 2
# category              4
# adulterant            4
# detection_date       12
# detection_method      1
# severity              0
# health_risk           1
# Name: 33, dtype: int64
# Row 33:************************************************** Investigation Launched
# adulteration_id     405
# product_name          4
# brand                 1
# category              2
# adulterant            0
# detection_date       18
# detection_method      1
# severity              0
# health_risk           0
# Name: 34, dtype: int64
# Row 34:************************************************** Investigation Launched
# adulteration_id     275
# product_name          6
# brand                 2
# category              0
# adulterant            2
# detection_date       60
# detection_method      2
# severity              0
# health_risk           1
# Name: 35, dtype: int64
# Row 35:************************************************** Product Recall
# adulteration_id     79
# product_name         3
# brand                2
# category             3
# adulterant           1
# detection_date      44
# detection_method     2
# severity             2
# health_risk          0
# Name: 36, dtype: int64
# Row 36:************************************************** Product Recall
# adulteration_id     722
# product_name          7
# brand                 4
# category              3
# adulterant            4
# detection_date       56
# detection_method      0
# severity              2
# health_risk           0
# Name: 37, dtype: int64
# Row 37:************************************************** Investigation Launched
# adulteration_id     645
# product_name          5
# brand                 0
# category              4
# adulterant            3
# detection_date       34
# detection_method      0
# severity              1
# health_risk           0
# Name: 38, dtype: int64
# Row 38:************************************************** Investigation Launched
# adulteration_id     615
# product_name          4
# brand                 4
# category              1
# adulterant            2
# detection_date       69
# detection_method      2
# severity              2
# health_risk           0
# Name: 39, dtype: int64
# Row 39:************************************************** Investigation Launched
# adulteration_id     873
# product_name          7
# brand                 2
# category              2
# adulterant            4
# detection_date       65
# detection_method      2
# severity              0
# health_risk           0
# Name: 40, dtype: int64
# Row 40:************************************************** Investigation Launched
# adulteration_id     692
# product_name          8
# brand                 3
# category              1
# adulterant            0
# detection_date       28
# detection_method      1
# severity              1
# health_risk           2
# Name: 41, dtype: int64
# Row 41:************************************************** Investigation Launched
# adulteration_id     91
# product_name         4
# brand                1
# category             0
# adulterant           1
# detection_date      13
# detection_method     3
# severity             0
# health_risk          2
# Name: 42, dtype: int64
# Row 42:************************************************** Investigation Launched
# adulteration_id     102
# product_name          6
# brand                 2
# category              4
# adulterant            1
# detection_date       48
# detection_method      0
# severity              2
# health_risk           2
# Name: 43, dtype: int64
# Row 43:************************************************** Product Recall
# adulteration_id     95
# product_name         2
# brand                3
# category             3
# adulterant           3
# detection_date      67
# detection_method     0
# severity             2
# health_risk          2
# Name: 44, dtype: int64
# Row 44:************************************************** Product Recall
# adulteration_id     578
# product_name          7
# brand                 3
# category              1
# adulterant            4
# detection_date       15
# detection_method      2
# severity              1
# health_risk           2
# Name: 45, dtype: int64
# Row 45:************************************************** Investigation Launched
# adulteration_id     538
# product_name          4
# brand                 3
# category              1
# adulterant            3
# detection_date       11
# detection_method      1
# severity              0
# health_risk           1
# Name: 46, dtype: int64
# Row 46:************************************************** Investigation Launched
# adulteration_id     42
# product_name         7
# brand                3
# category             0
# adulterant           0
# detection_date      47
# detection_method     1
# severity             2
# health_risk          1
# Name: 47, dtype: int64
# Row 47:************************************************** Product Recall
# adulteration_id     454
# product_name          9
# brand                 4
# category              3
# adulterant            4
# detection_date       40
# detection_method      3
# severity              0
# health_risk           1
# Name: 48, dtype: int64
# Row 48:************************************************** Investigation Launched
# adulteration_id     996
# product_name          2
# brand                 3
# category              1
# adulterant            0
# detection_date       59
# detection_method      0
# severity              0
# health_risk           2
# Name: 49, dtype: int64
# Row 49:************************************************** Investigation Launched
# adulteration_id     714
# product_name          7
# brand                 4
# category              0
# adulterant            4
# detection_date       27
# detection_method      2
# severity              0
# health_risk           1
# Name: 50, dtype: int64
# Row 50:************************************************** Investigation Launched
# adulteration_id     35
# product_name         6
# brand                4
# category             4
# adulterant           4
# detection_date      72
# detection_method     3
# severity             1
# health_risk          1
# Name: 51, dtype: int64
# Row 51:************************************************** Product Recall
# adulteration_id     640
# product_name          5
# brand                 1
# category              2
# adulterant            0
# detection_date       43
# detection_method      0
# severity              2
# health_risk           0
# Name: 52, dtype: int64
# Row 52:************************************************** Investigation Launched
# adulteration_id     36
# product_name         5
# brand                4
# category             1
# adulterant           3
# detection_date       8
# detection_method     1
# severity             2
# health_risk          2
# Name: 53, dtype: int64
# Row 53:************************************************** Product Recall
# adulteration_id     149
# product_name          4
# brand                 4
# category              4
# adulterant            0
# detection_date       13
# detection_method      2
# severity              0
# health_risk           0
# Name: 54, dtype: int64
# Row 54:************************************************** Investigation Launched
# adulteration_id     456
# product_name          7
# brand                 4
# category              3
# adulterant            2
# detection_date       16
# detection_method      2
# severity              1
# health_risk           1
# Name: 55, dtype: int64
# Row 55:************************************************** Investigation Launched
# adulteration_id     886
# product_name          7
# brand                 1
# category              4
# adulterant            4
# detection_date       15
# detection_method      0
# severity              1
# health_risk           1
# Name: 56, dtype: int64
# Row 56:************************************************** Investigation Launched
# adulteration_id     678
# product_name          1
# brand                 0
# category              2
# adulterant            4
# detection_date        3
# detection_method      2
# severity              1
# health_risk           2
# Name: 57, dtype: int64
# Row 57:************************************************** Investigation Launched
# adulteration_id     487
# product_name          2
# brand                 4
# category              1
# adulterant            3
# detection_date       36
# detection_method      3
# severity              2
# health_risk           0
# Name: 58, dtype: int64
# Row 58:************************************************** Investigation Launched
# adulteration_id     686
# product_name          4
# brand                 1
# category              3
# adulterant            4
# detection_date       53
# detection_method      0
# severity              2
# health_risk           1
# Name: 59, dtype: int64
# Row 59:************************************************** Investigation Launched
# adulteration_id     308
# product_name          4
# brand                 0
# category              2
# adulterant            1
# detection_date       50
# detection_method      0
# severity              2
# health_risk           2
# Name: 60, dtype: int64
# Row 60:************************************************** Product Recall
# adulteration_id     239
# product_name          4
# brand                 2
# category              4
# adulterant            2
# detection_date       58
# detection_method      3
# severity              0
# health_risk           2
# Name: 61, dtype: int64
# Row 61:************************************************** Product Recall
# adulteration_id     396
# product_name          2
# brand                 1
# category              3
# adulterant            3
# detection_date       70
# detection_method      0
# severity              0
# health_risk           0
# Name: 62, dtype: int64
# Row 62:************************************************** Product Recall
# adulteration_id     735
# product_name          9
# brand                 2
# category              3
# adulterant            1
# detection_date       19
# detection_method      1
# severity              2
# health_risk           1
# Name: 63, dtype: int64
# Row 63:************************************************** Investigation Launched
# adulteration_id     823
# product_name          1
# brand                 1
# category              2
# adulterant            2
# detection_date       67
# detection_method      2
# severity              1
# health_risk           2
# Name: 64, dtype: int64
# Row 64:************************************************** Investigation Launched
# adulteration_id     813
# product_name          6
# brand                 4
# category              3
# adulterant            0
# detection_date       41
# detection_method      2
# severity              0
# health_risk           1
# Name: 65, dtype: int64
# Row 65:************************************************** Investigation Launched
# adulteration_id     465
# product_name          6
# brand                 4
# category              0
# adulterant            2
# detection_date       40
# detection_method      3
# severity              0
# health_risk           0
# Name: 66, dtype: int64
# Row 66:************************************************** Investigation Launched
# adulteration_id     817
# product_name          1
# brand                 1
# category              3
# adulterant            3
# detection_date       30
# detection_method      1
# severity              0
# health_risk           1
# Name: 67, dtype: int64
# Row 67:************************************************** Investigation Launched
# adulteration_id     529
# product_name          1
# brand                 2
# category              2
# adulterant            1
# detection_date        9
# detection_method      2
# severity              1
# health_risk           1
# Name: 68, dtype: int64
# Row 68:************************************************** Investigation Launched
# adulteration_id     18
# product_name         9
# brand                1
# category             0
# adulterant           1
# detection_date      58
# detection_method     3
# severity             1
# health_risk          0
# Name: 69, dtype: int64
# Row 69:************************************************** Product Recall
# adulteration_id     710
# product_name          9
# brand                 4
# category              0
# adulterant            2
# detection_date       20
# detection_method      1
# severity              1
# health_risk           2
# Name: 70, dtype: int64
# Row 70:************************************************** Investigation Launched
# adulteration_id     371
# product_name          8
# brand                 3
# category              1
# adulterant            4
# detection_date       26
# detection_method      3
# severity              2
# health_risk           2
# Name: 71, dtype: int64
# Row 71:************************************************** Investigation Launched
# adulteration_id     242
# product_name          6
# brand                 2
# category              1
# adulterant            2
# detection_date       70
# detection_method      1
# severity              0
# health_risk           0
# Name: 72, dtype: int64
# Row 72:************************************************** Product Recall
# adulteration_id     965
# product_name          4
# brand                 3
# category              3
# adulterant            1
# detection_date       37
# detection_method      0
# severity              1
# health_risk           2
# Name: 73, dtype: int64
# Row 73:************************************************** Investigation Launched
# adulteration_id     458
# product_name          5
# brand                 1
# category              1
# adulterant            0
# detection_date        4
# detection_method      2
# severity              0
# health_risk           1
# Name: 74, dtype: int64
# Row 74:************************************************** Investigation Launched
# adulteration_id     66
# product_name         4
# brand                3
# category             3
# adulterant           0
# detection_date      10
# detection_method     3
# severity             0
# health_risk          2
# Name: 75, dtype: int64
# Row 75:************************************************** Investigation Launched
# adulteration_id     192
# product_name          7
# brand                 2
# category              4
# adulterant            4
# detection_date       58
# detection_method      3
# severity              1
# health_risk           2
# Name: 76, dtype: int64
# Row 76:************************************************** Product Recall
# adulteration_id     839
# product_name          1
# brand                 0
# category              1
# adulterant            0
# detection_date       42
# detection_method      2
# severity              2
# health_risk           0
# Name: 77, dtype: int64
# Row 77:************************************************** Investigation Launched
# adulteration_id     332
# product_name          2
# brand                 1
# category              3
# adulterant            3
# detection_date       63
# detection_method      1
# severity              2
# health_risk           0
# Name: 78, dtype: int64
# Row 78:************************************************** Product Recall
# adulteration_id     639
# product_name          0
# brand                 4
# category              2
# adulterant            0
# detection_date       41
# detection_method      2
# severity              1
# health_risk           1
# Name: 79, dtype: int64
# Row 79:************************************************** Investigation Launched
# adulteration_id     256
# product_name          5
# brand                 3
# category              1
# adulterant            0
# detection_date        0
# detection_method      0
# severity              2
# health_risk           0
# Name: 80, dtype: int64
# Row 80:************************************************** Product Recall
# adulteration_id     743
# product_name          6
# brand                 0
# category              4
# adulterant            4
# detection_date       66
# detection_method      0
# severity              0
# health_risk           2
# Name: 81, dtype: int64
# Row 81:************************************************** Investigation Launched
# adulteration_id     757
# product_name          5
# brand                 0
# category              4
# adulterant            0
# detection_date       33
# detection_method      1
# severity              1
# health_risk           2
# Name: 82, dtype: int64
# Row 82:************************************************** Investigation Launched
# adulteration_id     758
# product_name          3
# brand                 0
# category              1
# adulterant            4
# detection_date       31
# detection_method      0
# severity              2
# health_risk           2
# Name: 83, dtype: int64
# Row 83:************************************************** Investigation Launched
# adulteration_id     952
# product_name          5
# brand                 2
# category              0
# adulterant            0
# detection_date       23
# detection_method      3
# severity              0
# health_risk           2
# Name: 84, dtype: int64
# Row 84:************************************************** Investigation Launched
# adulteration_id     993
# product_name          4
# brand                 4
# category              4
# adulterant            1
# detection_date       32
# detection_method      0
# severity              2
# health_risk           1
# Name: 85, dtype: int64
# Row 85:************************************************** Investigation Launched
# adulteration_id     464
# product_name          2
# brand                 4
# category              0
# adulterant            0
# detection_date       68
# detection_method      2
# severity              2
# health_risk           0
# Name: 86, dtype: int64
# Row 86:************************************************** Product Recall
# adulteration_id     844
# product_name          8
# brand                 4
# category              4
# adulterant            4
# detection_date        4
# detection_method      3
# severity              0
# health_risk           1
# Name: 87, dtype: int64
# Row 87:************************************************** Investigation Launched
# adulteration_id     574
# product_name          3
# brand                 2
# category              3
# adulterant            0
# detection_date       57
# detection_method      2
# severity              1
# health_risk           2
# Name: 88, dtype: int64
# Row 88:************************************************** Investigation Launched
# adulteration_id     528
# product_name          8
# brand                 0
# category              3
# adulterant            3
# detection_date       30
# detection_method      1
# severity              0
# health_risk           1
# Name: 89, dtype: int64
# Row 89:************************************************** Investigation Launched
# adulteration_id     655
# product_name          3
# brand                 1
# category              3
# adulterant            3
# detection_date        6
# detection_method      1
# severity              2
# health_risk           2
# Name: 90, dtype: int64
# Row 90:************************************************** Investigation Launched
# adulteration_id     190
# product_name          6
# brand                 3
# category              0
# adulterant            1
# detection_date       23
# detection_method      3
# severity              2
# health_risk           1
# Name: 91, dtype: int64
# Row 91:************************************************** Product Recall
# adulteration_id     518
# product_name          9
# brand                 2
# category              1
# adulterant            2
# detection_date        2
# detection_method      3
# severity              1
# health_risk           0
# Name: 92, dtype: int64
# Row 92:************************************************** Product Recall
# adulteration_id     957
# product_name          2
# brand                 2
# category              4
# adulterant            4
# detection_date       24
# detection_method      3
# severity              1
# health_risk           0
# Name: 93, dtype: int64
# Row 93:************************************************** Investigation Launched
# adulteration_id     415
# product_name          2
# brand                 1
# category              3
# adulterant            1
# detection_date       17
# detection_method      0
# severity              0
# health_risk           1
# Name: 94, dtype: int64
# Row 94:************************************************** Investigation Launched
# adulteration_id     672
# product_name          2
# brand                 2
# category              2
# adulterant            4
# detection_date        1
# detection_method      3
# severity              1
# health_risk           1
# Name: 95, dtype: int64
# Row 95:************************************************** Investigation Launched
# adulteration_id     560
# product_name          7
# brand                 0
# category              3
# adulterant            3
# detection_date       39
# detection_method      3
# severity              2
# health_risk           2
# Name: 96, dtype: int64
# Row 96:************************************************** Investigation Launched
# adulteration_id     594
# product_name          5
# brand                 3
# category              1
# adulterant            2
# detection_date       58
# detection_method      3
# severity              1
# health_risk           1
# Name: 97, dtype: int64
# Row 97:************************************************** Investigation Launched
# adulteration_id     259
# product_name          4
# brand                 1
# category              1
# adulterant            0
# detection_date       15
# detection_method      2
# severity              1
# health_risk           2
# Name: 98, dtype: int64
# Row 98:************************************************** Investigation Launched
# adulteration_id     155
# product_name          4
# brand                 0
# category              0
# adulterant            0
# detection_date       62
# detection_method      3
# severity              1
# health_risk           0
# Name: 99, dtype: int64
# Row 99:************************************************** Product Recall

# %%
test['predict']=predict

# %%
test
# Out:
#     adulteration_id  product_name  brand  category  adulterant  \
# 0               508             8      3         1           2
# 1               819             4      3         1           4
# 2               453             8      4         0           1
# 3               369             7      2         2           3
# 4               243             4      3         4           2
# ..              ...           ...    ...       ...         ...
# 95              672             2      2         2           4
# 96              560             7      0         3           3
# 97              594             5      3         1           2
# 98              259             4      1         1           0
# 99              155             4      0         0           0
#
#     detection_date  detection_method  severity  health_risk  predict
# 0               49                 3         1            1        3
# 1               49                 1         1            2        3
# 2                5                 0         0            1        2
# 3               21                 3         2            0        3
# 4               61                 1         2            0        2
# ..             ...               ...       ...          ...      ...
# 95               1                 3         1            1        3
# 96              39                 3         2            2        3
# 97              58                 3         1            1        3
# 98              15                 2         1            2        3
# 99              62                 3         1            0        2
#
# [100 rows x 10 columns]

# %%
mapping = {0: 'Fine Imposed', 1: 'Warning Issued', 2: 'Product Recall', 3: 'Investigation Launched'}

# %%
test['predict'] = test['predict'].map(mapping)

# %%
test
# Out:
#     adulteration_id  product_name  brand  category  adulterant  \
# 0               508             8      3         1           2
# 1               819             4      3         1           4
# 2               453             8      4         0           1
# 3               369             7      2         2           3
# 4               243             4      3         4           2
# ..              ...           ...    ...       ...         ...
# 95              672             2      2         2           4
# 96              560             7      0         3           3
# 97              594             5      3         1           2
# 98              259             4      1         1           0
# 99              155             4      0         0           0
#
#     detection_date  detection_method  severity  health_risk  \
# 0               49                 3         1            1
# 1               49                 1         1            2
# 2                5                 0         0            1
# 3               21                 3         2            0
# 4               61                 1         2            0
# ..             ...               ...       ...          ...
# 95               1                 3         1            1
# 96              39                 3         2            2
# 97              58                 3         1            1
# 98              15                 2         1            2
# 99              62                 3         1            0
#
#                    predict
# 0   Investigation Launched
# 1   Investigation Launched
# 2           Product Recall
# 3   Investigation Launched
# 4           Product Recall
# ..                     ...
# 95  Investigation Launched
# 96  Investigation Launched
# 97  Investigation Launched
# 98  Investigation Launched
# 99          Product Recall
#
# [100 rows x 10 columns]
